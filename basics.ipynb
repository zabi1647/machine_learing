# %% [markdown]
# <a href="https://colab.research.google.com/github/zabi1647/machine_learing/blob/main/basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy

# %%
print("hello world")
# Out:
# hello world

# %%
import numpy as np
matrix = np.random.randint(60,100,(5,5))
mat = np.random.randint(60,100,(5,5))
print(np.dot(matrix,mat))
# Out:
# [[33944 31745 32300 29951 32317]
#  [34478 32273 33283 30696 33142]
#  [31030 29196 29751 28009 29693]
#  [32447 30694 31358 29120 31070]
#  [32629 30570 31167 29673 31209]]

# %%
import matplotlib.pyplot as plt
import numpy as np
x =np.array([1,2,3,4,5])

y = x ** 2 + 3
# plt.style.use('seaborn')
plt.plot(x,y,label="stock Price")
plt.plot(x,x**2+x,label="stock Price")
plt.title("My line plot")
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt
img = cv2.imread('/content/complete web.jpg')
rbg_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
grey_img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
crop_img = rbg_img[250:550,150:450,:]
crop_img = cv2.resize(crop_img,(100,100))
# plt.imshow(rbg_img)
# # plt.imshow(grey_img)
# plt.show()

# %%
# plt.imshow(rbg_img)
plt.imshow(crop_img)
# plt.show()
crop_img.shape
# Out:
# (100, 100, 3)

# %%
import numpy as np
import pandas as pd

pokemons = {
    "pikachu": np.random.randint(1,100,5),
    "bulbasaur":np.random.randint(50,100,5),
    "tarzon":np.random.randint(50,100,5),
    "luffy":np.random.randint(50,100,5),
    "zoro":np.random.randint(50,100,5),
}
df = pd.DataFrame(pokemons)
df = pd.read_csv('/content/pokemon.csv')
# df.head()
df.shape
# Out:
# (5, 6)
